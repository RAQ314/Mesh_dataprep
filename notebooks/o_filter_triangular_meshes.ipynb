# %%
import objaverse
import pandas as pd
from typing import Any, Dict, Hashable
import tqdm
import urllib

import open3d as o3d

import pathlib

objaverse.__version__
# Out:
# Jupyter environment detected. Enabling Open3D WebVisualizer.
# [Open3D INFO] WebRTC GUI backend enabled.
# [Open3D INFO] WebRTCWindowSystem: HTTP handshake server disabled.
# '0.1.7'

# %%
all_uids=objaverse.load_uids()
print(f"Loaded {len(all_uids)} UIDs")
all_annotations=objaverse.load_annotations(all_uids)
# print(f"Loaded {len(all_annotations)} annotations")
# df=pd.DataFrame.from_dict(all_annotations,orient="index")
# print(df.head())
# print(df.columns)
# df.head(2000).to_csv("./output/objaverse-1.0_annotations.csv")
# Out:
# Loaded 798759 UIDs
#  99%|█████████▉| 159/160 [00:31<00:00,  5.12it/s]

# %%
#----- Download all .obj files with less than 500 faces
maxNumberOfFaces=500
download_dir=f"./output/objaverse-1.0_obj_files_{maxNumberOfFaces}"
pathlib.Path(download_dir).mkdir(parents=True,exist_ok=True)

# %%
#--- Filter uuid refering models with less than maxNumberOfFaces faces
filteredUids=[]

for uuid in tqdm.tqdm(all_uids) :
    #annotation=objaverse.load_annotations([uuid])
    annotation=all_annotations[uuid]
    #print(annotation)
    if int(annotation["faceCount"])<=maxNumberOfFaces :
        filteredUids.append(uuid)

        # if len(filteredUids)>10 :
        #     break

print(f"Found {len(filteredUids)} objects with less than {maxNumberOfFaces} faces")
# Out:
# 100%|██████████| 798759/798759 [00:00<00:00, 1593748.61it/s]
# Found 67439 objects with less than 500 faces

# %%
#--- Save annotations of filtered objects
filteredAnnotations=objaverse.load_annotations(filteredUids)
df=pd.DataFrame.from_dict(filteredAnnotations,orient="index")
df.to_csv(f"./output/objaverse-1.0_annotations_less_than_{maxNumberOfFaces}_faces.csv")
# Out:
#  99%|█████████▉| 159/160 [00:29<00:00,  5.36it/s]

# %%
# #--- Download filtered models
# filteredObjects=objaverse.load_objects(filteredUids, download_processes=4)

# %%
# #--- Convert the object to .obj files and save them
# for uuid, localPath in tqdm.tqdm(filteredObjects.items()) :
#     mesh=o3d.io.read_triangle_mesh(localPath)
#     if len(mesh.triangles)>0 :
#         meshName=pathlib.Path(localPath).stem
#         meshToSave=o3d.geometry.TriangleMesh
#         meshToSave.vertices=mesh.vertices
#         meshToSave.triangles=mesh.triangles
#         o3d.io.write_triangle_mesh(f"{download_dir}/{uuid} - {meshName}.obj", meshToSave)
#     pathlib.Path(localPath).unlink()  #--- Delete the downloaded file to save space

# %%
#--- Download filtered models
savedMeshUids=[]

for filtered_uuid in tqdm.tqdm(filteredUids) :
    localObject=objaverse.load_objects([filtered_uuid])
    localPath=localObject[filtered_uuid]

    mesh=o3d.io.read_triangle_mesh(localPath)
    if len(mesh.triangles)>0 and len(mesh.triangles)<=maxNumberOfFaces :
        meshName=pathlib.Path(localPath).stem
        meshToSave=o3d.geometry.TriangleMesh(mesh.vertices, mesh.triangles)
        o3d.io.write_triangle_mesh(f"{download_dir}/{uuid} - {meshName}.obj", meshToSave)
        savedMeshUids.append(filtered_uuid)
    
    pathlib.Path(localPath).unlink()  #--- Delete the downloaded file to save space

print(f"Saved {len(savedMeshUids)} .obj files with less than {maxNumberOfFaces} faces")
# Out:
#   0%|          | 1/67439 [00:00<8:18:56,  2.25it/s]
# [Open3D INFO] Skipping non-triangle primitive geometry of type: 1
#   0%|          | 3/67439 [00:01<12:40:53,  1.48it/s]
# Downloaded 1 / 1 objects
#   0%|          | 4/67439 [00:02<12:55:23,  1.45it/s]
# Downloaded 1 / 1 objects
# Downloaded 1 / 1 objects
#   0%|          | 5/67439 [00:04<20:13:12,  1.08s/it]
# [Open3D INFO] Skipping non-triangle primitive geometry of type: 1
# Downloaded 1 / 1 objects
#   0%|          | 6/67439 [00:11<57:13:30,  3.06s/it]
# [Open3D INFO] Skipping non-triangle primitive geometry of type: 1
# Downloaded 1 / 1 objects
#   0%|          | 7/67439 [00:13<50:52:26,  2.72s/it]
# [Open3D INFO] Skipping non-triangle primitive geometry of type: 1
# Downloaded 1 / 1 objects
#   0%|          | 8/67439 [00:19<74:04:14,  3.95s/it]
# [Open3D INFO] Skipping non-triangle primitive geometry of type: 1
#   0%|          | 9/67439 [00:20<55:00:20,  2.94s/it]
# Downloaded 1 / 1 objects
#   0%|          | 10/67439 [00:21<42:40:52,  2.28s/it]
# Downloaded 1 / 1 objects
#   0%|          | 11/67439 [00:22<33:41:33,  1.80s/it]
# Downloaded 1 / 1 objects
#   0%|          | 12/67439 [00:22<27:52:59,  1.49s/it]
# Downloaded 1 / 1 objects
#   0%|          | 13/67439 [00:23<23:49:03,  1.27s/it]
# Downloaded 1 / 1 objects
# [Open3D INFO] Skipping non-triangle primitive geometry of type: 2
# [Open3D INFO] Skipping non-triangle primitive geometry of type: 2
#   0%|          | 14/67439 [00:24<20:42:44,  1.11s/it]
# Downloaded 1 / 1 objects
#   0%|          | 15/67439 [00:25<18:18:36,  1.02it/s]
# Downloaded 1 / 1 objects
#   0%|          | 16/67439 [00:25<17:05:19,  1.10it/s]
# Downloaded 1 / 1 objects
#   0%|          | 17/67439 [00:26<16:21:51,  1.14it/s]
# Downloaded 1 / 1 objects
#   0%|          | 18/67439 [00:27<15:27:41,  1.21it/s]
# Downloaded 1 / 1 objects
#   0%|          | 19/67439 [00:28<15:07:59,  1.24it/s]
# Downloaded 1 / 1 objects
#   0%|          | 20/67439 [00:28<14:42:17,  1.27it/s]
# Downloaded 1 / 1 objects
#   0%|          | 21/67439 [00:29<14:12:26,  1.32it/s]
# Downloaded 1 / 1 objects
#   0%|          | 22/67439 [00:30<14:03:22,  1.33it/s]
# Downloaded 1 / 1 objects
#   0%|          | 23/67439 [00:30<13:48:30,  1.36it/s]
# Downloaded 1 / 1 objects
# Downloaded 1 / 1 objects
#   0%|          | 24/67439 [00:33<23:45:46,  1.27s/it]
# [Open3D INFO] Skipping non-triangle primitive geometry of type: 1
#   0%|          | 25/67439 [00:34<20:44:16,  1.11s/it]
# Downloaded 1 / 1 objects
#   0%|          | 26/67439 [00:35<19:34:46,  1.05s/it]
# Downloaded 1 / 1 objects
#   0%|          | 27/67439 [00:35<17:48:39,  1.05it/s]
# Downloaded 1 / 1 objects
#   0%|          | 28/67439 [00:36<16:29:07,  1.14it/s]
# Downloaded 1 / 1 objects
#   0%|          | 29/67439 [00:37<15:54:35,  1.18it/s]
# Downloaded 1 / 1 objects
#   0%|          | 30/67439 [00:37<15:06:43,  1.24it/s]
# Downloaded 1 / 1 objects
#   0%|          | 31/67439 [00:38<14:33:14,  1.29it/s]
# Downloaded 1 / 1 objects
#   0%|          | 32/67439 [00:39<14:14:03,  1.32it/s]
# Downloaded 1 / 1 objects
#   0%|          | 33/67439 [00:40<13:56:44,  1.34it/s]
# Downloaded 1 / 1 objects
#   0%|          | 34/67439 [00:40<14:32:26,  1.29it/s]
# Downloaded 1 / 1 objects
#   0%|          | 35/67439 [00:41<14:13:44,  1.32it/s]
# Downloaded 1 / 1 objects
# Downloaded 1 / 1 objects
#   0%|          | 36/67439 [00:46<34:58:49,  1.87s/it]
# [Open3D INFO] Skipping non-triangle primitive geometry of type: 1
#   0%|          | 37/67439 [00:46<28:32:59,  1.52s/it]
# Downloaded 1 / 1 objects
#   0%|          | 38/67439 [00:47<24:18:58,  1.30s/it]
# Downloaded 1 / 1 objects
#   0%|          | 39/67439 [00:48<21:30:47,  1.15s/it]
# Downloaded 1 / 1 objects
#   0%|          | 40/67439 [00:49<19:59:05,  1.07s/it]
# Downloaded 1 / 1 objects
#   0%|          | 41/67439 [00:50<18:21:58,  1.02it/s]
# Downloaded 1 / 1 objects
#   0%|          | 42/67439 [00:50<17:41:41,  1.06it/s]
# Downloaded 1 / 1 objects
# [Open3D INFO] Skipping non-triangle primitive geometry of type: 2
#   0%|          |
  1.30it/s]
# Downloaded 1 / 1 objects
#   0%|          | 316/67439 [05:46<14:25:21,  1.29it/s]
# Downloaded 1 / 1 objects
#   0%|          | 317/67439 [05:47<15:36:40,  1.19it/s]
# Downloaded 1 / 1 objects
#   0%|          | 318/67439 [05:48<16:13:07,  1.15it/s]
# Downloaded 1 / 1 objects
#   0%|          | 319/67439 [05:49<15:37:01,  1.19it/s]
# Downloaded 1 / 1 objects
#   0%|          | 320/67439 [05:50<14:59:01,  1.24it/s]
# Downloaded 1 / 1 objects
#   0%|          | 321/67439 [05:50<14:23:17,  1.30it/s]
# Downloaded 1 / 1 objects
#   0%|          | 322/67439 [05:51<14:02:59,  1.33it/s]
# Downloaded 1 / 1 objects
#   0%|          | 323/67439 [05:52<14:17:07,  1.31it/s]
# Downloaded 1 / 1 objects
#   0%|          | 324/67439 [05:53<14:04:59,  1.32it/s]
# Downloaded 1 / 1 objects
#   0%|          | 325/67439 [05:53<13:43:17,  1.36it/s]
# Downloaded 1 / 1 objects
#   0%|          | 326/67439 [05:54<13:57:32,  1.34it/s]
# Downloaded 1 / 1 objects
#   0%|          | 327/67439 [05:55<13:47:04,  1.35it/s]
# Downloaded 1 / 1 objects
#   0%|          | 328/67439 [05:56<14:08:37,  1.32it/s]
# Downloaded 1 / 1 objects
#   0%|          | 329/67439 [05:57<14:49:49,  1.26it/s]
# Downloaded 1 / 1 objects
#   0%|          | 330/67439 [05:57<14:48:09,  1.26it/s]
# Downloaded 1 / 1 objects
#   0%|          | 331/67439 [05:58<14:35:36,  1.28it/s]
# Downloaded 1 / 1 objects
#   0%|          | 332/67439 [05:59<16:27:33,  1.13it/s]
# Downloaded 1 / 1 objects
#   0%|          | 333/67439 [06:00<16:48:56,  1.11it/s]
# Downloaded 1 / 1 objects
#   0%|          | 334/67439 [06:01<16:00:14,  1.16it/s]
# Downloaded 1 / 1 objects
#   0%|          | 335/67439 [06:02<15:25:18,  1.21it/s]
# Downloaded 1 / 1 objects
#   0%|          | 336/67439 [06:02<14:45:37,  1.26it/s]
# Downloaded 1 / 1 objects
#   0%|          | 337/67439 [06:04<16:37:04,  1.12it/s]
# Downloaded 1 / 1 objects
#   1%|          | 338/67439 [06:04<16:02:43,  1.16it/s]
# Downloaded 1 / 1 objects
#   1%|          | 339/67439 [06:05<15:40:42,  1.19it/s]
# Downloaded 1 / 1 objects
#   1%|          | 340/67439 [06:06<15:53:01,  1.17it/s]
# Downloaded 1 / 1 objects
#   1%|          | 341/67439 [06:07<15:36:29,  1.19it/s]
# Downloaded 1 / 1 objects
#   1%|          | 342/67439 [06:08<15:27:02,  1.21it/s]
# Downloaded 1 / 1 objects
#   1%|          | 343/67439 [06:08<15:15:09,  1.22it/s]
# Downloaded 1 / 1 objects
#   1%|          | 344/67439 [06:09<15:00:40,  1.24it/s]
# Downloaded 1 / 1 objects
# Downloaded 1 / 1 objects
#   1%|          | 345/67439 [06:13<34:34:54,  1.86s/it]
# [Open3D INFO] Skipping non-triangle primitive geometry of type: 1
#   1%|          | 346/67439 [06:14<28:57:39,  1.55s/it]
# Downloaded 1 / 1 objects
#   1%|          | 347/67439 [06:15<25:55:41,  1.39s/it]
# Downloaded 1 / 1 objects
#   1%|          | 348/67439 [06:16<22:52:04,  1.23s/it]
# Downloaded 1 / 1 objects
#   1%|          | 349/67439 [06:17<21:28:28,  1.15s/it]
# Downloaded 1 / 1 objects
#   1%|          | 350/67439 [06:18<19:37:09,  1.05s/it]
# Downloaded 1 / 1 objects
#   1%|          | 351/67439 [06:19<18:16:50,  1.02it/s]
# Downloaded 1 / 1 objects
#   1%|          | 352/67439 [06:20<16:52:05,  1.10it/s]
# Downloaded 1 / 1 objects
#   1%|          | 353/67439 [06:20<16:25:23,  1.13it/s]
# Downloaded 1 / 1 objects
#   1%|          | 354/67439 [06:21<16:04:50,  1.16it/s]
# Downloaded 1 / 1 objects
#   1%|          | 355/67439 [06:22<15:24:56,  1.21it/s]
# Downloaded 1 / 1 objects
#   1%|          | 356/67439 [06:23<15:12:25,  1.23it/s]
# Downloaded 1 / 1 objects
#   1%|          | 357/67439 [06:24<15:29:18,  1.20it/s]
# Downloaded 1 / 1 objects
#   1%|          | 358/67439 [06:24<16:05:01,  1.16it/s]
# Downloaded 1 / 1 objects
#   1%|          | 359/67439 [06:25<15:58:36,  1.17it/s]
# Downloaded 1 / 1 objects
#   1%|          | 360/67439 [06:26<15:23:00,  1.21it/s]
# Downloaded 1 / 1 objects
#   1%|          | 361/67439 [06:27<14:51:51,  1.25it/s]
# Downloaded 1 / 1 objects
#   1%|          | 362/67439 [06:28<14:33:30,  1.28it/s]
# Downloaded 1 / 1 objects
#   1%|          | 363/67439 [06:28<15:02:31,  1.24it/s]
# Downloaded 1 / 1 objects
#   1%|          | 364/67439 [06:29<15:52:23,  1.17it/s]
# Downloaded 1 / 1 objects
# Downloaded 1 / 1 objects
#   1%|          | 365/67439 [06:32<27:54:00,  1.50s/it]
# [Open3D INFO] Skipping non-triangle primitive geometry of type: 1
#   1%|          | 366/67439 [06:33<25:08:10,  1.35s/it]
# Downloaded 1 / 1 objects
#   1%|          | 367/67439 [06:34<22:25:31,  1.20s/it]
# Downloaded 1 / 1 objects
# Downloaded 1 / 1 objects
#   1%|          | 368/67439 [06:41<53:31:27,  2.87s/it]
# [Open3D INFO] Skipping non-triangle primitive geometry of type: 1
#   1%|          | 369/67439 [06:42<41:32:23,  2.23s/it]
# Downloaded 1 / 1 objects
#   1%|          | 370/67439 [06:42<33:09:54,  1.78s/it]
# Downloaded 1 / 1 objects
#   1%|          | 371/67439 [06:44<28:54:10,  1.55s/it]
# Downloaded 1 / 1 objects
# [Open3D INFO] Skipping non-triangle primitive geometry of type: 1
#   1%|          | 372/67439 [06:44<24:21:36,  1.31s/it]
# Downloaded 1 / 1 objects
# Downloaded 1 / 1 objects
#   1%|          | 373/67439 [06:51<55:05:39,  2.96s/it]
# [Open3D INFO] Skipping non-triangle primitive geometry of type: 1
#   1%|          | 374/67439 [06:52<42:46:19,  2.30s/it]
# Downloaded 1 / 1 objects
#   1%|          | 375/67439 [06:53<34:22:27,  1.85s/it]
# Downloaded 1 / 1 objects
#   1%|          | 376/67439 [06:53<29:03:56,  1.56s/it]
# Downloaded 1 / 1 objects
#   1%|          | 377/67439 [06:54<24:45:49,  1.33s/it]
# Downloaded 1 / 1 objects
#   1%|          | 378/67439 [06:55<21:22:25,  1.15s/it]
# Downloaded 1 / 1 objects
#   1%|          | 379/67439 [06:56<19:13:09,  1.03s/it]
# Downloaded 1 / 1 objects
#   1%|          | 380/67439 [06:57<18:13:07,  1.02it/s]
# Downloaded 1 / 1 objects
#   1%|          | 381/67439 [06:57<17:39:49,  1.05it/s]
# Downloaded 1 / 1 objects
# Downloaded 1 / 1 objects
#   1%|          | 382/67439 [07:03<42:47:04,  2.30s/it]
# [Open3D INFO] Skipping non-triangle primitive geometry of type: 1
#   1%|          | 383/67439 [07:04<34:08:03,  1.83s/it]
# Downloaded 1 / 1 objects
# Downloaded 1 / 1 objects
#   1%|          | 384/67439 [07:06<35:08:51,  1.89s/it]
# [Open3D INFO] Skipping non-triangle primitive geometry of type: 1
#   1%|          | 385/67439 [07:07<29:05:28,  1.56s/it]
# Downloaded 1 / 1 objects
#   1%|          | 386/67439 [07:07<24:48:14,  1.33s/it]
# Downloaded 1 / 1 objects
#   1%|          | 387/67439 [07:08<21:39:59,  1.16s/it]
# Downloaded 1 / 1 objects
#   1%|          | 388/67439 [07:09<20:44:01,  1.11s/it]
# Downloaded 1 / 1 objects
#   1%|          | 389/67439 [07:10<18:50:44,  1.01s/it]
# Downloaded 1 / 1 objects
#   1%|          | 390/67439 [07:11<17:46:46,  1.05it/s]
# Downloaded 1 / 1 objects
#   1%|          | 391/67439 [07:11<16:54:17,  1.10it/s]
# Downloaded 1 / 1 objects
#   1%|          | 392/67439 [07:13<18:04:29,  1.03it/s]
# Downloaded 1 / 1 objects
# [Open3D INFO] Skipping non-triangle primitive geometry of type: 1
#   1%|          | 393/67439 [07:13<17:02:05,  1.09it/s]
# Downloaded 1 / 1 objects
#   1%|          | 394/67439 [07:14<16:38:36,  1.12it/s]
# Downloaded 1 / 1 objects
#   1%|          | 395/67439 [07:15<16:06:15,  1.16it/s]
# Downloaded 1 / 1 objects
#   1%|          | 396/67439 [07:16<15:16:23,  1.22it/s]
# Downloaded 1 / 1 objects
#   1%|          | 397/67439 [07:16<14:57:08,  1.25it/s]
# Downloaded 1 / 1 objects
#   1%|          | 398/67439 [07:17<14:44:59,  1.26it/s]
# Downloaded 1 / 1 objects
#   1%|          | 399/67439 [07:18<14:23:02,  1.29it/s]
# Downloaded 1 / 1 objects
#   1%|          | 400/67439 [07:19<14:10:00,  1.31it/s]
# Downloaded 1 / 1 objects
#   1%|          | 401/67439 [07:19<14:07:05,  1.32it/s]
# Downloaded 1 / 1 objects
# Downloaded 1 / 1 objects
#   1%|          | 402/67439 [07:26<48:35:17,  2.61s/it]
# [Open3D INFO] Skipping non-triangle primitive geometry of type: 1
# Downloaded 1 / 1 objects
#   1%|          | 403/67439 [07:39<105:42:20,  5.68s/it]
# [Open3D INFO] Skipping non-triangle primitive geometry of type: 1
# Downloaded 1 / 1 objects
#   1%|          | 404/67439 [07:41<85:48:41,  4.61s/it]
# [Open3D INFO] Skipping non-triangle primitive geometry of type: 1
#   1%|          | 405/67439 [07:42<65:01:41,  3.49s/it]
# Downloaded 1 / 1 objects
#   1%|          | 406/67439 [07:43<50:14:29,  2.70s/it]
# Downloaded 1 / 1 objects
#   1%|          | 407/67439 [07:44<39:31:46,  2.12s/it]
# Downloaded 1 / 1 objects
# [Open3D INFO] Skipping non-triangle primitive geometry of type: 2
# [Open3D INFO] Skipping non-triangle primitive geometry of type: 2
# [Open3D INFO] Skipping non-triangle primitive geometry of type: 2
#   1%|          | 408/67439 [07:45<31:52:31,  1.71s/it]
# Downloaded 1 / 1 objects
#   1%|          | 409/67439 [07:46<27:31:18,  1.48s/it]
# Downloaded 1 / 1 objects
#   1%|          | 410/67439 [07:47<24:44:49,  1.33s/it]
# Downloaded 1 / 1 objects
#   1%|          | 411/67439 [07:47<21:45:49,  1.17s/it]
# Downloaded 1 / 1 objects
#   1%|          | 412/67439 [07:48<19:30:20,  1.05s/it]
# Downloaded 1 / 1 objects
# [Open3D INFO] Skipping non-triangle primitive geometry of type: 2
#   1%|          | 413/67439 [07:49<18:55:51,  1.02s/it]
# Downloaded 1 / 1 objects
#   1%|          | 414/67439 [07:50<17:28:32,  1.07it/s]
# Downloaded 1 / 1 objects
#   1%|          | 415/67439 [07:51<17:24:45,  1.07it/s]
# Downloaded 1 / 1 objects
#   1%|          | 416/67439 [07:52<16:37:47,  1.12it/s]
# Downloaded 1 / 1 objects
#   1%|          | 417/67439 [07:52<15:55:49,  1.17it/s]
# Downloaded 1 / 1 objects
#   1%|          | 418/67439 [07:53<15:33:14,  1.20it/s]
# Downloaded 1 / 1 objects
#   1%|          | 419/67439 [07:54<16:25:41,  1.13it/s]
# Downloaded 1 / 1 objects
#   1%|          | 420/67439 [07:55<16:31:43,  1.13it/s]
# Downloaded 1 / 1 objects
#   1%|          | 421/67439 [07:56<18:34:56,  1.00it/s]
# Downloaded 1 / 1 objects
#   1%|          | 422/67439 [07:57<17:32:10,  1.06it/s]
# Downloaded 1 / 1 objects
#   1%|          | 423/67439 [07:58<16:31:09,  1.13it/s]
# Downloaded 1 / 1 objects
#   1%|          | 424/67439 [07:59<16:36:44,  1.12it/s]
# Downloaded 1 / 1 objects
#   1%|          | 425/67439 [08:00<16:54:14,  1.10it/s]
# Downloaded 1 / 1 objects
#   1%|          | 426/67439 [08:01<17:21:00,  1.07it/s]
# Downloaded 1 / 1 objects
# Downloaded 1 / 1 objects
#   1%|          | 427/67439 [08:10<66:12:55,  3.56s/it]
# [Open3D INFO] Skipping non-triangle primitive geometry of type: 1
#   1%|          | 428/67439 [08:11<52:09:30,  2.80s/it]
# Downloaded 1 / 1 objects
#   1%|          | 429/67439 [08:12<41:42:42,  2.24s/it]
# Downloaded 1 / 1 objects
#   1%|          | 430/67439 [08:13<34:18:45,  1.84s/it]
# Downloaded 1 / 1 objects
#   1%|          | 431/67439 [08:14<28:40:31,  1.54s/it]
# Downloaded 1 / 1 objects
#   1%|          | 432/67439 [08:15<25:19:06,  1.36s/it]
# Downloaded 1 / 1 objects
#   1%|          | 433/67439 [08:16<22:19:12,  1.20s/it]
# Downloaded 1 / 1 objects
#   1%|          | 434/67439 [08:17<19:58:25,  1.07s/it]
# Downloaded 1 / 1 objects
#   1%|          | 435/67439 [08:17<18:02:50,  1.03it/s]
# Downloaded 1 / 1 objects
#   1%|          | 436/67439 [08:18<16:40:16,  1.12it/s]
# Downloaded 1 / 1 objects
#   1%|          | 437/67439 [08:19<15:44:55,  1.18it/s]
# Downloaded 1 / 1 objects
#   1%|          | 438/67439 [08:20<17:50:07,  1.04it/s]
# Downloaded 1 / 1 objects
#   1%|          | 439/67439 [08:21<18:53:26,  1.02s/it]
# Downloaded 1 / 1 objects
#   1%|          | 440/67439 [08:22<18:16:59,  1.02it/s]
# Downloaded 1 / 1 objects
#   1%|          | 441/67439 [08:23<18:12:19,  1.02it/s]
# Downloaded 1 / 1 objects
#   1%|          | 442/67439 [08:24<19:00:51,  1.02s/it]
# Downloaded 1 / 1 objects
#   1%|          | 443/67439 [08:25<18:28:17,  1.01it/s]
# Downloaded 1 / 1 objects
#   1%|          | 444/67439 [08:26<17:45:16,  1.05it/s]
# Downloaded 1 / 1 objects
#   1%|          | 445/67439 [08:27<17:46:08,  1.05it/s]
# Downloaded 1 / 1 objects
#   1%|          | 446/67439 [08:28<17:27:48,  1.07it/s]
# Downloaded 1 / 1 objects
#   1%|          | 447/67439 [08:29<18:18:36,  1.02it/s]
# Downloaded 1 / 1 objects
# [Open3D INFO] Skipping non-triangle primitive geometry of type: 1
#   1%|          | 448/67439 [08:30<17:32:43,  1.06it/s]
# Downloaded 1 / 1 objects
#   1%|          | 449/67439 [08:31<17:14:37,  1.08it/s]
# Downloaded 1 / 1 objects
#   1%|          | 450/67439 [08:31<16:57:53,  1.10it/s]
# Downloaded 1 / 1 objects
# Downloaded 1 / 1 objects
#   1%|          | 451/67439 [08:35<30:01:35,  1.61s/it]
# [Open3D INFO] Skipping non-triangle primitive geometry of type: 1
#   1%|          | 452/67439 [08:36<27:05:38,  1.46s/it]
# Downloaded 1 / 1 objects
#   1%|          | 453/67439 [08:37<23:34:59,  1.27s/it]
# Downloaded 1 / 1 objects
#   1%|          | 454/67439 [08:38<21:54:00,  1.18s/it]
# Downloaded 1 / 1 objects
# Downloaded 1 / 1 objects
#   1%|          | 455/67439 [08:43<45:50:51,  2.46s/it]
# [Open3D INFO] Skipping non-triangle primitive geometry of type: 1
#   1%|          | 456/67439 [08:44<36:38:50,  1.97s/it]
# Downloaded 1 / 1 objects
#   1%|          | 457/67439 [08:45<31:48:52,  1.71s/it]
# Downloaded 1 / 1 objects
#   1%|          | 458/67439 [08:46<27:10:42,  1.46s/it]
# Downloaded 1 / 1 objects
#   1%|          | 459/67439 [08:47<24:14:57,  1.30s/it]
# Downloaded 1 / 1 objects
#   1%|          | 460/67439 [08:48<23:52:46,  1.28s/it]
# Downloaded 1 / 1 objects
#   1%|          | 461/67439 [08:49<21:46:10,  1.17s/it]
# Downloaded 1 / 1 objects
#   1%|          | 462/67439 [08:50<20:05:20,  1.08s/it]
# Downloaded 1 / 1 objects
#   1%|          | 463/67439 [08:51<19:07:55,  1.03s/it]
# Downloaded 1 / 1 objects
#   1%|          | 464/67439 [08:52<18:25:57,  1.01it/s]
# Downloaded 1 / 1 objects
#   1%|          | 464/67439 [08:55<21:28:55,  1.15s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 5
#       2 savedMeshUids=[]
#       4 for filtered_uuid in tqdm.tqdm(filteredUids) :
# ----> 5     localObject=objaverse.load_objects([filtered_uuid])
#       6     localPath=localObject[filtered_uuid]
#       8     mesh=o3d.io.read_triangle_mesh(localPath)
#
# File e:\dev\repos\condaEnvs\objaverse\lib\site-packages\objaverse\__init__.py:162, in load_objects(uids, download_processes)
#     158     start_file_count = len(
#     159         glob.glob(os.path.join(_VERSIONED_PATH, "glbs", "*", "*.glb"))
#     160     )
#     161     for uid, object_path in uids_to_download:
# --> 162         uid, local_path = _download_object(
#     163             uid, object_path, len(uids_to_download), start_file_count
#     164         )
#     165         out[uid] = local_path
#     166 else:
#
# File e:\dev\repos\condaEnvs\objaverse\lib\site-packages\objaverse\__init__.py:111, in _download_object(uid, object_path, total_downloads, start_file_count)
#     109 # wget the file and put it in local_path
#     110 os.makedirs(os.path.dirname(tmp_local_path), exist_ok=True)
# --> 111 urllib.request.urlretrieve(hf_url, tmp_local_path)
#     113 os.rename(tmp_local_path, local_path)
#     115 files = glob.glob(os.path.join(_VERSIONED_PATH, "glbs", "*", "*.glb"))
#
# File e:\dev\repos\condaEnvs\objaverse\lib\urllib\request.py:270, in urlretrieve(url, filename, reporthook, data)
#     267     reporthook(blocknum, bs, size)
#     269 while True:
# --> 270     block = fp.read(bs)
#     271     if not block:
#     272         break
#
# File e:\dev\repos\condaEnvs\objaverse\lib\http\client.py:466, in HTTPResponse.read(self, amt)
#     463 if self.length is not None and amt > self.length:
#     464     # clip the read to the "end of response"
#     465     amt = self.length
# --> 466 s = self.fp.read(amt)
#     467 if not s and amt:
#     468     # Ideally, we would raise IncompleteRead if the content-length
#     469     # wasn't satisfied, but it might break compatibility.
#     470     self._close_conn()
#
# File e:\dev\repos\condaEnvs\objaverse\lib\socket.py:717, in SocketIO.readinto(self, b)
#     715 while True:
#     716     try:
# --> 717         return self._sock.recv_into(b)
#     718     except timeout:
#     719         self._timeout_occurred = True
#
# File e:\dev\repos\condaEnvs\objaverse\lib\ssl.py:1307, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1303     if flags != 0:
#    1304         raise ValueError(
#    1305           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1306           self.__class__)
# -> 1307     return self.read(nbytes, buffer)
#    1308 else:
#    1309     return super().recv_into(buffer, nbytes, flags)
#
# File e:\dev\repos\condaEnvs\objaverse\lib\ssl.py:1163, in SSLSocket.read(self, len, buffer)
#    1161 try:
#    1162     if buffer is not None:
# -> 1163         return self._sslobj.read(len, buffer)
#    1164     else:
#    1165         return self._sslobj.read(len)
#
# KeyboardInterrupt:
